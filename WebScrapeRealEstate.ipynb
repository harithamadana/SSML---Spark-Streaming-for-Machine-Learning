# %% [markdown]
# <a href="https://colab.research.google.com/github/harithamadana/SSML---Spark-Streaming-for-Machine-Learning/blob/main/WebScrapeRealEstate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This project is done in order to create a dataset that has information of the serial killers based on the number of victims.
# I have considered the "List of serial killers by number of victims" article on wikipedia for this project.
# Here is the link to it: https://en.wikipedia.org/wiki/List_of_serial_killers_by_number_of_victims

# %% [markdown]
# ## Step 1: Downloading the web page using "requests" library

# %% [markdown]
# Here we will be downloading the web page using the "requests" library.
# First, we will install and import it:

# %%
# Install the library
# !pip install requests --quiet

# %%
#importing requests library
import requests

# %% [markdown]
# Now, we will download the web page using requests.get() function.
#
# Here is the syntax of this function:
# response_object= requests.get(url_of_your_page)
#
# Here is the url used: https://en.wikipedia.org/wiki/List_of_serial_killers_by_number_of_victims

# %%
# Downloading the web page
url="https://en.wikipedia.org/wiki/List_of_serial_killers_by_number_of_victims"
response= requests.get(url)

# %% [markdown]
# response is a requests.get object that has the page contents and indication of whether execution was successful or not.
# If successful, requests.status_code gives us a value between 200 and 299

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# Web page download was successful!
#
# Now we can view the contents of the web page using response.text
#
# Note: The "contents" referred to here is the source code which is in HTML

# %%
source_code=response.text
len(source_code)
# Out:
# 1118827

# %% [markdown]
# That's so many characters! In order to examine the contents, let's view the first 2000 characters

# %%
source_code[0:2000]
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>List of serial killers by number of victims - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"adff91b1-7772-4a35-bd5b-1025b8ba752a","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"List_of_serial_killers_by_number_of_victims","wgTitle":"List of serial killers by number of victims","wgCurRevisionId":1098918268,"wgRevisionId":1098918268,"wgArticleId":1779164,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Webarchive template wayback links","CS1 Spanish-languag
# ...

# %% [markdown]
# In order to make this code better to read, I will be saving it as an html file and opening it on colab- which is where I'm running it right now.

# %%
with open('list_serial_killers.html', 'w', encoding="utf-8") as file:
    file.write(source_code)

# %% [markdown]
# This is what my screen looks like after the process:
# ![image.png](data:image/png;base64,...)
